# %%
import requests
import re
import os
from bs4 import BeautifulSoup
from urllib.parse import urlsplit
import nltk
from nltk.probability import FreqDist
import matplotlib
from underthesea import word_tokenize


path = 'Pre_Data2'
files = os.listdir(path)
D=[]
for file in files:
    f = open(f"{path}\{file}", "r", encoding="utf-8")
    for line in f:
    # Remove linebreak which is the last character of the string
        text = line[:-1]
        # Add item to the list
        D.append(text)
#print(D)

print("Number of words: ", len(D))
frequency_dist = FreqDist(D)

## show only th top 50 results
print(frequency_dist.most_common(50))

# ## Consider words with length greater than 3 and plot
large_words = dict([(k, v) for k, v in frequency_dist.items() if len(k) > 3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50, cumulative=False)

from wordcloud import WordCloud

wcloud = WordCloud().generate_from_frequencies(frequency_dist)
# plotting the wordcloud
import matplotlib.pyplot as plt

plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Number of words:  9674
# [('quán', 221), ('đi', 175), ('k', 158), ('ko', 119), ('gọi', 118), ('món', 118), ('nhân_viên', 111), ('uống', 100), ('mấy', 85), ('phục_vụ', 84), ('ngon', 76), ('trà', 66), ('order', 65), ('bàn', 63), ('đông', 59), ('hơi', 59), ('chỗ', 57), ('thử', 55), ('n', 55), ('lắm', 54), ('đồ_ăn', 54), ('xong', 53), ('kêu', 51), ('tiền', 51), ('giá', 50), ('i', 49), ('rau', 47), ('bò', 46), ('đc', 44), ('ng', 42), ('xe', 41), ('sữa', 41), ('chờ', 39), ('dĩa', 36), ('t', 36), ('rẻ', 35), ('mùi', 35), ('h', 34), ('nh', 34), ('bảo', 33), ('đem', 32), ('đợi', 32), ('chạy', 32), ('kiểu', 31), ('chụp', 30), ('c', 30), ('đồ', 29), ('bánh', 29), ('m', 29), ('chẳng', 28)]
